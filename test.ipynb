# %%
import seaborn as sns 
import pandas as pd

# %%
df = pd.read_csv('./data/CN-Reanalysis-daily-2013010100.csv')
df.head(3)
# Out:
#    PM2.5   PM10    SO2   NO2    CO     O3  U(m/s)  V(m/s)  TEMP(K)  RH(%)  \
# 0  20.21  23.56   8.65  4.58  0.29  63.44   -2.48   -2.31   291.54  68.14
# 1  20.41  23.96   9.28  5.24  0.29  62.53   -3.43   -3.21   291.96  67.41
# 2  21.17  24.78  10.07  5.47  0.30  62.24   -3.43   -4.72   291.37  69.59
#
#     PSFC(Pa)    lat     lon
# 0  100350.11  18.34  109.25
# 1  100546.63  18.34  109.38
# 2  100428.13  18.33  109.52

# %%
df.columns
# Out:
# Index(['PM2.5', 'PM10', 'SO2', 'NO2', 'CO', 'O3', 'U(m/s)', 'V(m/s)',
#        'TEMP(K)', 'RH(%)', 'PSFC(Pa)', 'lat', 'lon', ' '],
#       dtype='object')

# %%
sns.scatterplot(data=df, x="lat", y="lon", hue="O3")
# Out:
# <AxesSubplot:xlabel='lat', ylabel='lon'>
